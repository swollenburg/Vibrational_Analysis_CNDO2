# %% [markdown]
# # Analysis Notebook
# This notebook is used to calculate the average bond distance between different molecules. Coordinates obtained from the output can be inserted here.

# %%
import math

def dist(a, b):
    return math.sqrt((a[0]-b[0])**2 + (a[1]-b[1])**2 + (a[2]-b[2])**2)

# %% [markdown]
# ### CO2

# %%
o1 = [-2.224459836, 6.367753376e-11, -7.323049538e-12]
c = [1.611710805e-10, -1.275578972e-10, 1.47964302e-11]
o2 = [2.224459836, 6.388036342e-11, -7.473380659e-12]
print(dist(o1, c))
print(dist(c, o2))
print()
print((dist(o1, c) + dist(c, o2))/2)
# Out:
# 2.224459836161171
# 2.224459835838829
#
# 2.224459836

# %% [markdown]
# ### NH3

# %%
# The average bond distance of the input file
n = [2.0876691167, 2.0876691167, 2.0876691167]
h1 = [3.5981025329, 2.5321406061, 1.0524930939]
h2 = [1.0524930939, 3.5981025329, 2.5321406061]
h3 = [2.5321406061, 1.0524930939, 3.5981025329]

print(dist(n, h1))
print(dist(n, h2))
print(dist(n, h3))
print()
print((dist(n, h1) + dist(n, h2) + dist(n, h3))/3)
# Out:
# 1.8842912216117451
# 1.8842912216117451
# 1.8842912216117453
#
# 1.8842912216117451

# %%
# The average bond distance of the output file
n = [0.7322824636, 0.7322824634, 0.7322824637]
h1 = [3.279052612, 2.895640057, 2.363430215]
h2 = [2.363430214, 3.279052611, 2.895640056]
h3 = [2.89564006, 2.363430218, 3.279052614]

n = [1.086828608, 1.086828608, 1.086828608]
h1 = [3.311242656, 2.794682305, 2.077651782]
h2 = [2.077651782, 3.311242656, 2.794682305]
h3 = [2.794682305, 2.077651782, 3.311242656]

print(dist(n, h1))
print(dist(n, h2))
print(dist(n, h3))
print()
print((dist(n, h1) + dist(n, h2) + dist(n, h3))/3)
# Out:
# 2.974308771703393
# 2.974308771703393
# 2.974308771703393
#
# 2.974308771703393

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    """
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    """
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].

xs = np.array([2.0876691167,3.5981025329,1.0524930939,2.5321406061])
ys = np.array([2.0876691167,2.5321406061,3.5981025329,1.0524930939])
zs = np.array([2.0876691167,1.0524930939,2.5321406061,3.5981025329])
ax.scatter(xs, ys, zs, marker='o', label='Original')

# xs = np.array([2.0876691167,3.5981025329,1.0524930939,2.5321406061])
# ys = np.array([0.7322824634,2.895640057,3.279052611,2.363430218]) 
# zs = np.array([0.7322824637,2.363430215,2.895640056,3.279052614])
xs = np.array([2.065112225,3.61804533, 1.046165143,2.541082652,])
ys = np.array([2.065112225,2.541082652,3.61804533, 1.046165143,]) 
zs = np.array([2.065112225,1.046165143,2.541082652,3.61804533])
ax.scatter(xs, ys, zs, marker='^', label='Optimized')


# 2.065112225, 2.065112225, 2.065112225
# 3.61804533,  2.541082652, 1.046165143
# 1.046165143, 3.61804533,  2.541082652
# 2.541082652, 1.046165143, 3.61804533

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.view_init(30,45)

plt.legend()
plt.show()

# %%
O = [0,0,0.11779]
h1 = [0,0.75545,-0.47116]
h2 = [0,-0.75545, -0.4716]

print(dist(O, h1))
print(dist(O, h2))
print()
# print((dist(n, h1) + dist(n, h2) + dist(n, h3))/3)
# Out:
# 0.9578970743247941
# 0.9581676651818304

# %%
O = [0,0,0.2225908242]
h1 = [0,1.4275934981,-0.8903632968]
h2 = [0,-1.4275934981, -0.8903632968]

print(dist(O, h1))
print(dist(O, h2))
print()
# Out:
# 1.8101629957736616
# 1.8101629957736616
